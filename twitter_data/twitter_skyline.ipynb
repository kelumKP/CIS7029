# %%
import tweepy
import pandas as pd

# %%
consumer_key = "L45cVwt1PcimfFnycMhQEHRsg"
consumer_secret = "a2f3dr6xHHukbCzlvzK5j0mDYg3di3aN8EfixXOhzV9dbhMk1F"
access_token = "1533339797187883008-A5uEjCSsKsH4OBeTaO8g0vHaqoI8h6"
access_token_secret = "UKvwBMeTRN6p4f2ogcrQAQT52Fi6eWUhe2pCnEkaJ8UGq"

# %%
auth = tweepy.OAuth1UserHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
number_of_tweets = 1000
tweets = []
likes = []
time = []
person_name = "Sky Line"
twitter_username = "SLRE777"


for i in tweepy.Cursor(api.user_timeline, id = twitter_username, tweet_mode = "extended").items(number_of_tweets):
    tweets.append(i.full_text)
    likes.append(i.favorite_count)
    time.append(i.created_at)
# Out:
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id

# %%
df = pd.DataFrame({'tweets': tweets, 'likes': likes, 'time': time})

# %%
df
# Out:
#                                                tweets  likes  \
# 0   Super Luxury Apartment – Coral City https://t....      1
# 1   Super Luxury Apartment – Coral Plus https://t....      1
# 2   Super Luxury Apartment – Coral Saffron https:/...      1
# 3   Like our Facebook page to keep you updated wit...      1
# 4   JOIN SkyLine Real Estate WHATSAPP group to kee...      1
# 5   Mount Lavinia, Colombo, Sri Lanka https://t.co...      1
# 6   Kalubowila, Colombo, Sri Lanka https://t.co/6l...      1
# 7   Kalalgoda, Colombo, Sri Lanka https://t.co/Qko...      1
# 8   Piliyandala, Colombo, Sri Lanka https://t.co/t...      1
# 9   Colpetty, Colombo 03, Colombo, Sri Lanka https...      1
# 10  Mount Lavinia, Mount Lavinia, Colombo, Sri Lan...      1
# 11  Pelawatte, Pelawatte, Colombo, Sri Lanka https...      1
# 12  Mabola, Mabola, Gampaha, Sri Lanka https://t.c...      1
# 13  Colombo 15, Colombo 15, Colombo, Sri Lanka htt...      1
# 14  Wattala, Wattala, Gampaha, Sri Lanka https://t...      1
# 15  Pelawatta, Pelawatta, Colombo, Sri Lanka https...      1
# 16  Siddamulla, Siddamulla, Colombo, Sri Lanka htt...      1
# 17  Gonapola, Gonapola, Colombo, Sri Lanka https:/...      1
# 18  Kawdana Road Land for Sale https://t.co/4TfHne...      1
# 19  Piliyandala, Colombo, Sri Lanka https://t.co/B...      1
# 20  Nugegoda, Colombo, Sri Lanka https://t.co/Wpnv...      1
# 21  Malabe, Colombo, Sri Lanka https://t.co/Er9ERb...      1
# 22  Nawalapitiya, Kandy, Sri Lanka https://t.co/Er...      2
# 23  Ibbagamuwa, Kurunegala, Sri Lanka https://t.co...      1
# 24  3 Storey Living House with Roof Top Plunge Poo...      1
# 25  Elegant House For Sale In Piliyandala Area htt...      1
# 26  Land in Baddegama, Hikkaduwa https://t.co/ulFj...      1
# 27  Large Bungalow at Colombo 3 for Rent https://t...      1
# 22 2017-04-23 12:59:17+00:00
# 23 2017-04-07 17:07:25+00:00
# 24 2017-04-06 16:30:20+00:00
# 25 2017-04-04 09:34:36+00:00
# 26 2017-04-04 05:05:01+00:00
# 27 2017-04-03 16:48:30+00:00
# 28 2017-04-03 16:47:44+00:00
# 29 2017-04-03 16:45:16+00:00
# 30 2017-03-19 08:00:31+00:00
# 31 2017-03-19 07:57:07+00:00

# %%
mostlike = df.loc[df.likes.nlargest(5).index]

# %%
mostlike
# Out:
#                                                tweets  likes  \
# 20  Nawalapitiya, Kandy, Sri Lanka https://t.co/Er...      2
# 31  Architect Designed Two Storied Luxury House at...      2
# 0   Super Luxury Apartment – Coral City https://t....      1
# 1   Super Luxury Apartment – Coral Plus https://t....      1
# 2   Super Luxury Apartment – Coral Saffron https:/...      1
#
#                         time
# 20 2017-04-23 17:32:35+00:00
# 31 2017-03-19 07:57:07+00:00
# 0  2017-09-22 02:46:20+00:00
# 1  2017-09-22 02:43:56+00:00
# 2  2017-09-22 02:40:23+00:00

# %%
import matplotlib.pyplot as plt
import re
import spacy
nlp = spacy.load("en_core_web_lg")
import seaborn as sns

# %%
list_of_sentences = [sentence for sentence in df.tweets]

lines = []
for sentence in list_of_sentences:
    words = sentence.split()
    for w in words:
        lines.append(w)

# %%
lines = [re.sub(r'[^A-Za-z0-9]+','',x) for x in lines]

lines2 = []

for word in lines:
    if word != '':
        lines2.append(word)

# %%
import nltk
from nltk.stem.snowball import SnowballStemmer

s_stemmer = SnowballStemmer(language='english')

stem = []
for word in lines2:
    stem.append(s_stemmer.stem(word))

# %%
stem2 = []

for word in stem:
    if word not in nlp.Defaults.stop_words:
        stem2.append(word)

# %%
df2 = pd.DataFrame(stem2)

df2 = df2[0].value_counts()

# %%
df2 = df2[:20,]
plt.figure(figsize=(10,5))
sns.barplot(df2.values, df2.index, alpha=1)
plt.title( person_name + ' Top Words Overall')
plt.ylabel('Word from Tweet', fontsize = 12)
plt.xlabel('Count of Words', fontsize = 12)
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
def show_ents(doc):
    if doc.ents:
        for ent in doc.ents:
            print(ent.text + ' _ ' + ent.label_ + ' _ ' + str(spacy.explain(ent.label_)))

# %%
str1 = " "
stem2 = str1.join(lines2)

stem2 = nlp(stem2)

label = [(X.text, X.label_) for X in stem2.ents]

df6 = pd.DataFrame(label, columns = ['Word', 'Entity'])

df7 = df6.where(df6['Entity'] == 'ORG')

df7 = df7['Word'].value_counts()

# %%
dfx = df7[:20,]
plt.figure(figsize=(10,5))
sns.barplot(dfx.values, dfx.index, alpha=1)
plt.title( person_name + ' Top Organizations Mentioned')
plt.ylabel('Word from Tweet', fontsize = 12)
plt.xlabel('Count of Words', fontsize = 12)
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
str1 = " "
stem2 = str1.join(lines2)

stem2 = nlp(stem2)

label = [(X.text, X.label_) for X in stem2.ents]

df10 = pd.DataFrame(label, columns = ['Word', 'Entity'])

df10 = df10.where(df6['Entity'] == 'PERSON')

df11 = df10['Word'].value_counts()

# %%
dfy = df11[:20,]
plt.figure(figsize=(10,5))
sns.barplot(dfy.values, dfy.index, alpha=1)
plt.title( person_name + ' Top People Mentioned')
plt.ylabel('Word from Tweet', fontsize = 12)
plt.xlabel('Count of Words', fontsize = 12)
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
