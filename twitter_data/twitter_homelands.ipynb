# %%
import tweepy
import pandas as pd

# %%
consumer_key = "L45cVwt1PcimfFnycMhQEHRsg"
consumer_secret = "a2f3dr6xHHukbCzlvzK5j0mDYg3di3aN8EfixXOhzV9dbhMk1F"
access_token = "1533339797187883008-A5uEjCSsKsH4OBeTaO8g0vHaqoI8h6"
access_token_secret = "UKvwBMeTRN6p4f2ogcrQAQT52Fi6eWUhe2pCnEkaJ8UGq"

# %%
auth = tweepy.OAuth1UserHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
number_of_tweets = 1000
tweets = []
likes = []
time = []
person_name = "Home Lands"
twitter_username = "lands_home"


for i in tweepy.Cursor(api.user_timeline, id = twitter_username, tweet_mode = "extended").items(number_of_tweets):
    tweets.append(i.full_text)
    likes.append(i.favorite_count)
    time.append(i.created_at)
# Out:
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id

# %%
df = pd.DataFrame({'tweets': tweets, 'likes': likes, 'time': time})

# %%
df
# Out:
#                                                tweets  likes  \
# 0   Home Lands Group of Companies is rebranding!\n...      0
# 1   @elonmusk @richardbranson @SpaceX @inspiration...     15
# 2   @elonmusk @richardbranson @SpaceX @inspiration...     15
# 3   Purchase your dream land at our high value loc...      0
# 4   බත බුලතින් කිරි ඉතිරෙන නව වසරේ Home Lands සමඟ ...      0
# 5   සුන්දර කන්ද උඩරටින් අගනා නේවාසික සහ ව්‍යාපාරික...      0
# 6   මැල්සිරිපුර පන්සියගම සින්නක්කර ඔප්පු මැල්සිරිප...      0
# 7   හෝම් ලෑන්ඩ්ස් වෙතින් ශ්‍රී ලංකාවේ ප්‍රථම වරට ල...      0
# 8   හෝම් ලෑන්ඩ්ස් වෙතින් ශ්‍රී ලංකාවේ ප්‍රථම වරට ල...      0
# 9   Highway Corridor - Dodangoda\nදොඩංගොඩ අධිවේගී ...      0
# 10  මාතර - ඉසදීන් නගරය\nමාතර ඉසදීන් නගරයෙන් කිරි ප...      0
# 11  බත්තරමුල්ල නගර මධ්‍යයෙන් ඉතා අගනා නේවාසික බිම්...      0
# 12  ඉගුරුපත්විල අධිවේගී පිවිසුමට සමීපව කැකණදුර යටි...      0
# 13  අධිවේගී අන්තර් හුවමාරුවෙන් යලි පිබිදෙන නරම්මල\...      0
# 14  කොළඹ පාරට මුහුණලා මාරවිලට ආසන්නයෙන් නාත්තන්ඩ්ය...      0
# 15  සියල් සපිරි නිට්ටඹුව නගරයේ පදිංචි වන්න. මධ්‍යම...      0
# 16  ආයෝජනයට හොදම තැන\nසියලු පහසුකම් සහිත අලුත්ම අල...      0
# 17  ගාල්ල නගරයට නුදුරින් අගනා බිම් කොටස් සුවිශේෂී ...      0
# 18  සියල් සපිරි නිට්ටඹුව නගරයේ පදිංචි වන්න. මධ්‍යම...      0
# 19  දොඩංගොඩ අධිවේගී මාර්ගයට මුහුණලා අගනා නේවාසික බ...      0
# 20  බත්තරමුල්ල නගර මධ්‍යයෙන් ඉතා අගනා නේවාසික බිම්...      0
# 21  කුරුණෑගල දඹුල්ල ප්‍රදාන පාරට නුදුරින් සුන්දර ව...      0
# 22  RESTART SRI LANKA\nසියලු පහසුකම් සහිත අලුත්ම අ...      0
#
#                         time
# 0  2021-10-21 05:19:04+00:00
# 1  2021-09-17 00:35:16+00:00
# 2  2021-09-17 00:35:15+00:00
# 3  2021-08-14 05:48:09+00:00
# 4  2021-04-08 04:35:06+00:00
# 5  2021-03-27 04:14:10+00:00
# 6  2021-03-23 04:01:47+00:00
# 7  2021-01-18 08:26:20+00:00
# 8  2021-01-05 05:25:34+00:00
# 9  2020-12-17 05:53:23+00:00
# 10 2020-12-03 10:42:51+00:00
# 11 2020-11-11 05:42:25+00:00
# 12 2020-10-26 10:33:36+00:00
# 13 2020-09-21 05:50:08+00:00
# 14 2020-09-12 04:27:48+00:00
# 15 2020-09-08 03:31:52+00:00
# 16 2020-08-22 07:22:11+00:00
# 17 2020-08-19 06:54:20+00:00
# 18 2020-08-12 10:00:59+00:00
# 19 2020-08-12 08:08:24+00:00
# 20 2020-08-12 06:44:10+00:00
# 21 2020-08-12 06:41:51+00:00
# 22 2020-08-12 06:37:48+00:00

# %%
df = df[~df.tweets.str.contains("RT")]
df = df[~df.tweets.str.contains("amp")]

# %%
df
# Out:
#                                                tweets  likes  \
# 0   Home Lands Group of Companies is rebranding!\n...      0
# 1   @elonmusk @richardbranson @SpaceX @inspiration...     15
# 2   @elonmusk @richardbranson @SpaceX @inspiration...     15
# 3   Purchase your dream land at our high value loc...      0
# 4   බත බුලතින් කිරි ඉතිරෙන නව වසරේ Home Lands සමඟ ...      0
# 5   සුන්දර කන්ද උඩරටින් අගනා නේවාසික සහ ව්‍යාපාරික...      0
# 6   මැල්සිරිපුර පන්සියගම සින්නක්කර ඔප්පු මැල්සිරිප...      0
# 7   හෝම් ලෑන්ඩ්ස් වෙතින් ශ්‍රී ලංකාවේ ප්‍රථම වරට ල...      0
# 8   හෝම් ලෑන්ඩ්ස් වෙතින් ශ්‍රී ලංකාවේ ප්‍රථම වරට ල...      0
# 9   Highway Corridor - Dodangoda\nදොඩංගොඩ අධිවේගී ...      0
# 10  මාතර - ඉසදීන් නගරය\nමාතර ඉසදීන් නගරයෙන් කිරි ප...      0
# 11  බත්තරමුල්ල නගර මධ්‍යයෙන් ඉතා අගනා නේවාසික බිම්...      0
# 12  ඉගුරුපත්විල අධිවේගී පිවිසුමට සමීපව කැකණදුර යටි...      0
# 13  අධිවේගී අන්තර් හුවමාරුවෙන් යලි පිබිදෙන නරම්මල\...      0
# 14  කොළඹ පාරට මුහුණලා මාරවිලට ආසන්නයෙන් නාත්තන්ඩ්ය...      0
# 15  සියල් සපිරි නිට්ටඹුව නගරයේ පදිංචි වන්න. මධ්‍යම...      0
# 16  ආයෝජනයට හොදම තැන\nසියලු පහසුකම් සහිත අලුත්ම අල...      0
# 17  ගාල්ල නගරයට නුදුරින් අගනා බිම් කොටස් සුවිශේෂී ...      0
# 18  සියල් සපිරි නිට්ටඹුව නගරයේ පදිංචි වන්න. මධ්‍යම...      0
# 19  දොඩංගොඩ අධිවේගී මාර්ගයට මුහුණලා අගනා නේවාසික බ...      0
# 20  බත්තරමුල්ල නගර මධ්‍යයෙන් ඉතා අගනා නේවාසික බිම්...      0
# 21  කුරුණෑගල දඹුල්ල ප්‍රදාන පාරට නුදුරින් සුන්දර ව...      0
#
#                         time
# 0  2021-10-21 05:19:04+00:00
# 1  2021-09-17 00:35:16+00:00
# 2  2021-09-17 00:35:15+00:00
# 3  2021-08-14 05:48:09+00:00
# 4  2021-04-08 04:35:06+00:00
# 5  2021-03-27 04:14:10+00:00
# 6  2021-03-23 04:01:47+00:00
# 7  2021-01-18 08:26:20+00:00
# 8  2021-01-05 05:25:34+00:00
# 9  2020-12-17 05:53:23+00:00
# 10 2020-12-03 10:42:51+00:00
# 11 2020-11-11 05:42:25+00:00
# 12 2020-10-26 10:33:36+00:00
# 13 2020-09-21 05:50:08+00:00
# 14 2020-09-12 04:27:48+00:00
# 15 2020-09-08 03:31:52+00:00
# 16 2020-08-22 07:22:11+00:00
# 17 2020-08-19 06:54:20+00:00
# 18 2020-08-12 10:00:59+00:00
# 19 2020-08-12 08:08:24+00:00
# 20 2020-08-12 06:44:10+00:00
# 21 2020-08-12 06:41:51+00:00

# %%
df = df.reset_index(drop=True)

# %%
df
# Out:
#                                                tweets  likes  \
# 0   Home Lands Group of Companies is rebranding!\n...      0
# 1   @elonmusk @richardbranson @SpaceX @inspiration...     15
# 2   @elonmusk @richardbranson @SpaceX @inspiration...     15
# 3   Purchase your dream land at our high value loc...      0
# 4   බත බුලතින් කිරි ඉතිරෙන නව වසරේ Home Lands සමඟ ...      0
# 5   සුන්දර කන්ද උඩරටින් අගනා නේවාසික සහ ව්‍යාපාරික...      0
# 6   මැල්සිරිපුර පන්සියගම සින්නක්කර ඔප්පු මැල්සිරිප...      0
# 7   හෝම් ලෑන්ඩ්ස් වෙතින් ශ්‍රී ලංකාවේ ප්‍රථම වරට ල...      0
# 8   හෝම් ලෑන්ඩ්ස් වෙතින් ශ්‍රී ලංකාවේ ප්‍රථම වරට ල...      0
# 9   Highway Corridor - Dodangoda\nදොඩංගොඩ අධිවේගී ...      0
# 10  මාතර - ඉසදීන් නගරය\nමාතර ඉසදීන් නගරයෙන් කිරි ප...      0
# 11  බත්තරමුල්ල නගර මධ්‍යයෙන් ඉතා අගනා නේවාසික බිම්...      0
# 12  ඉගුරුපත්විල අධිවේගී පිවිසුමට සමීපව කැකණදුර යටි...      0
# 13  අධිවේගී අන්තර් හුවමාරුවෙන් යලි පිබිදෙන නරම්මල\...      0
# 14  කොළඹ පාරට මුහුණලා මාරවිලට ආසන්නයෙන් නාත්තන්ඩ්ය...      0
# 15  සියල් සපිරි නිට්ටඹුව නගරයේ පදිංචි වන්න. මධ්‍යම...      0
# 16  ආයෝජනයට හොදම තැන\nසියලු පහසුකම් සහිත අලුත්ම අල...      0
# 17  ගාල්ල නගරයට නුදුරින් අගනා බිම් කොටස් සුවිශේෂී ...      0
# 18  සියල් සපිරි නිට්ටඹුව නගරයේ පදිංචි වන්න. මධ්‍යම...      0
# 19  දොඩංගොඩ අධිවේගී මාර්ගයට මුහුණලා අගනා නේවාසික බ...      0
# 20  බත්තරමුල්ල නගර මධ්‍යයෙන් ඉතා අගනා නේවාසික බිම්...      0
# 21  කුරුණෑගල දඹුල්ල ප්‍රදාන පාරට නුදුරින් සුන්දර ව...      0
#
#                         time
# 0  2021-10-21 05:19:04+00:00
# 1  2021-09-17 00:35:16+00:00
# 2  2021-09-17 00:35:15+00:00
# 3  2021-08-14 05:48:09+00:00
# 4  2021-04-08 04:35:06+00:00
# 5  2021-03-27 04:14:10+00:00
# 6  2021-03-23 04:01:47+00:00
# 7  2021-01-18 08:26:20+00:00
# 8  2021-01-05 05:25:34+00:00
# 9  2020-12-17 05:53:23+00:00
# 10 2020-12-03 10:42:51+00:00
# 11 2020-11-11 05:42:25+00:00
# 12 2020-10-26 10:33:36+00:00
# 13 2020-09-21 05:50:08+00:00
# 14 2020-09-12 04:27:48+00:00
# 15 2020-09-08 03:31:52+00:00
# 16 2020-08-22 07:22:11+00:00
# 17 2020-08-19 06:54:20+00:00
# 18 2020-08-12 10:00:59+00:00
# 19 2020-08-12 08:08:24+00:00
# 20 2020-08-12 06:44:10+00:00
# 21 2020-08-12 06:41:51+00:00

# %%
mostlike = df.loc[df.likes.nlargest(5).index]

# %%
mostlike
# Out:
#                                               tweets  likes  \
# 1  @elonmusk @richardbranson @SpaceX @inspiration...     15
# 2  @elonmusk @richardbranson @SpaceX @inspiration...     15
# 0  Home Lands Group of Companies is rebranding!\n...      0
# 3  Purchase your dream land at our high value loc...      0
# 4  බත බුලතින් කිරි ඉතිරෙන නව වසරේ Home Lands සමඟ ...      0
#
#                        time
# 1 2021-09-17 00:35:16+00:00
# 2 2021-09-17 00:35:15+00:00
# 0 2021-10-21 05:19:04+00:00
# 3 2021-08-14 05:48:09+00:00
# 4 2021-04-08 04:35:06+00:00

# %%
import matplotlib.pyplot as plt
import re
import spacy
nlp = spacy.load("en_core_web_lg")
import seaborn as sns

# %%
list_of_sentences = [sentence for sentence in df.tweets]

lines = []
for sentence in list_of_sentences:
    words = sentence.split()
    for w in words:
        lines.append(w)

# %%
lines = [re.sub(r'[^A-Za-z0-9]+','',x) for x in lines]

lines2 = []

for word in lines:
    if word != '':
        lines2.append(word)

# %%
import nltk
from nltk.stem.snowball import SnowballStemmer

s_stemmer = SnowballStemmer(language='english')

stem = []
for word in lines2:
    stem.append(s_stemmer.stem(word))

# %%
stem2 = []

for word in stem:
    if word not in nlp.Defaults.stop_words:
        stem2.append(word)

# %%
df2 = pd.DataFrame(stem2)

df2 = df2[0].value_counts()

# %%
df2 = df2[:20,]
plt.figure(figsize=(10,5))
sns.barplot(df2.values, df2.index, alpha=1)
plt.title( person_name + ' Top Words Overall')
plt.ylabel('Word from Tweet', fontsize = 12)
plt.xlabel('Count of Words', fontsize = 12)
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
def show_ents(doc):
    if doc.ents:
        for ent in doc.ents:
            print(ent.text + ' _ ' + ent.label_ + ' _ ' + str(spacy.explain(ent.label_)))

# %%
str1 = " "
stem2 = str1.join(lines2)

stem2 = nlp(stem2)

label = [(X.text, X.label_) for X in stem2.ents]

df6 = pd.DataFrame(label, columns = ['Word', 'Entity'])

df7 = df6.where(df6['Entity'] == 'ORG')

df7 = df7['Word'].value_counts()

# %%
dfx = df7[:20,]
plt.figure(figsize=(10,5))
sns.barplot(dfx.values, dfx.index, alpha=1)
plt.title( person_name + ' Top Organizations Mentioned')
plt.ylabel('Word from Tweet', fontsize = 12)
plt.xlabel('Count of Words', fontsize = 12)
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
str1 = " "
stem2 = str1.join(lines2)

stem2 = nlp(stem2)

label = [(X.text, X.label_) for X in stem2.ents]

df10 = pd.DataFrame(label, columns = ['Word', 'Entity'])

df10 = df10.where(df6['Entity'] == 'PERSON')

df11 = df10['Word'].value_counts()

# %%
dfy = df11[:20,]
plt.figure(figsize=(10,5))
sns.barplot(dfy.values, dfy.index, alpha=1)
plt.title( person_name + ' Top People Mentioned')
plt.ylabel('Word from Tweet', fontsize = 12)
plt.xlabel('Count of Words', fontsize = 12)
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
